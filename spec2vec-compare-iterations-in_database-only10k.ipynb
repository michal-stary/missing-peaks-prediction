# %% [markdown]
# # Compare word2vec training  iterations (AllPositive dataset)

# %%
import os
import sys
import gensim
import numpy as np

base = "data"
dataset = "nist"
kind = "in_database"

model_name = kind + "_only10k"

data_train_path =f"{base}/{dataset}/{kind}/train.msp"
data_val_path =f"{base}/{dataset}/{kind}/val.msp"
data_test_path =f"{base}/{dataset}/{kind}/test.msp"

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Import pre-processed dataset "Unique InchiKeys"

# %%
from matchms.importing import load_from_msp
from data_utils import spectrum_processing

spectrums_val = [spectrum_processing(s) for s in load_from_msp(data_val_path)]
spectrums_val = [s for s in spectrums_val if s is not None]
print("number of spectra:", len(spectrums_val))
# Out:
# number of spectra: 22921

# %% [markdown]
# ## Load pretrained spec2vec models and calculate scores

# %%
from spec2vec import Spec2Vec
from spec2vec import SpectrumDocument

# %%
documents = [SpectrumDocument(s, n_decimals=0) for s in spectrums_val]

# %%
documents[0].words[:10]
# Out:
# ['peak@12',
#  'peak@13',
#  'peak@14',
#  'peak@15',
#  'peak@24',
#  'peak@25',
#  'peak@26',
#  'peak@27',
#  'peak@28',
#  'peak@29']

# %% [markdown]
# ### Load reference scores

# %%
filename = "gas2vec/similarity_nist_val/tanimoto_scores.npy"
matrix_similarities_fingerprint_daylight = np.load(filename)

# %%
from spec2vec_plotting_functions import plot_precentile

# %% [markdown]
# ## Actual score calculation
# + Using ``Spec2Vec`` with ``intensity_weighting_power=0.5``.
# + Calculate matrix of all-vs-all similarity scores.
# + Iterate over trained models after different numbers of iterations.

# %%
# !pwd
# Out:
# /auto/brno6/home/xstary1/raims

# %%
path_models = "gas2vec"

for iteration in [2, 4, 6, 10, 16, 20, 26, 30, 40, 50, 60, 70, 80, 90, 100]:
    filename = f"{model_name}_iter_{iteration}.model"
    model_file = os.path.join(path_models, filename)

    # Load pretrained model
    model = gensim.models.Word2Vec.load(model_file)
    
    # Score calculations
    spec2vec_similarity = Spec2Vec(model, intensity_weighting_power=0.5, allowed_missing_percentage=100)
    similarity_matrix = spec2vec_similarity.matrix(documents, documents, is_symmetric=True)
    print("u")
    # Compare to reference scores
    percentile_spec2vec = plot_precentile(matrix_similarities_fingerprint_daylight,
                                                      similarity_matrix,
                                                      num_bins=100, show_top_percentile=0.1,
                                                      ignore_diagonal=True)

    filename = os.path.join("gas2vec/iterations", "percentile_spec2vec_only10k_iter_{}.npy".format(iteration))
    np.save(filename, percentile_spec2vec)
    
    filename = os.path.join("gas2vec/iterations", "similarities_spec2vec_only10k_iter_{}.npy".format(iteration))
    np.save(filename, percentile_spec2vec)
# Out:
# Found 91 word(s) missing in the model. Weighted missing percentage not covered by the given model is 32.53%.
# Found 92 word(s) missing in the model. Weighted missing percentage not covered by the given model is 34.59%.
# Found 12 word(s) missing in the model. Weighted missing percentage not covered by the given model is 19.53%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.09%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.55%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.32%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.63%.
# Found 65 word(s) missing in the model. Weighted missing percentage not covered by the given model is 34.19%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.94%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.65%.
# Found 63 word(s) missing in the model. Weighted missing percentage not covered by the given model is 18.79%.
# Found 15 word(s) missing in the model. Weighted missing percentage not covered by the given model is 8.90%.
# Found 9 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.45%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.30%.
# Found 16 word(s) missing in the model. Weighted missing percentage not covered by the given model is 27.41%.
# Found 17 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.42%.
# Found 4 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.66%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.18%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.20%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.13%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.23%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.23%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.26%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.18%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.19%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.28%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.27%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.27%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.27%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.19%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.30%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.18%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.79%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.76%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.20%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.55%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.74%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.74%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.36%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.90%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.53%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.44%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.99%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.39%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.46%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.43%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.81%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.40%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.84%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.76%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.27%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.07%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.92%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.90%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.93%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.52%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.19%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.31%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.85%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.50%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.20%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.89%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.12%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.09%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.21%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.33%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.49%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.36%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.16%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.78%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.98%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.39%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.64%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.74%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.46%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.54%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.34%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.35%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.26%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.15%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.90%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.88%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.15%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.93%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.44%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.42%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.70%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.61%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.67%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.87%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.68%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.65%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.48%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.33%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.83%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.93%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.70%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.80%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.39%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.44%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.91%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.00%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.40%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.56%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.10%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.44%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.35%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.98%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.34%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.74%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.67%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.68%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.54%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.61%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.84%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.97%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.59%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.87%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.04%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.05%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.53%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.89%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.25%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.50%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.92%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.40%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.78%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.86%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.07%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.76%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.27%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.20%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.37%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.28%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.52%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.00%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.30%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.39%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.86%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.84%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 8.03%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 8.39%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.00%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.26%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.41%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 13.95%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.23%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.29%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.31%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.52%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.46%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.22%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.86%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.93%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.83%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.55%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.48%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.48%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.79%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.50%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.86%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.22%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.75%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.75%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.71%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 8.41%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.86%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.44%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.83%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.69%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.86%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.81%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.83%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.62%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.91%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.32%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 11.12%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.80%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.88%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.02%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.38%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 8.21%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.08%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.33%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.72%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.77%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.13%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.70%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.56%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.64%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.25%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.89%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.46%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.79%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.17%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.01%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.16%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.72%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 8.16%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.42%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 11.28%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 13.98%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 12.82%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 13.89%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 11.65%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 13.93%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 9.96%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 15.33%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 9.83%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.62%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.07%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.86%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.26%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.60%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.52%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.29%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.44%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.07%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.33%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 8.42%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.60%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.17%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.34%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.93%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.11%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.21%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.61%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.57%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.55%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.90%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.14%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.97%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.21%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.66%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 9.84%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 10.35%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 8.11%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 8.37%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.67%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 8.35%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.64%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.79%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.92%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 9.21%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 9.55%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 11.41%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.75%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.95%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 9.09%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.54%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.78%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.40%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.08%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.00%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.40%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.11%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.27%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.24%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.23%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.29%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.45%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.16%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.42%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.01%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.84%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.91%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.72%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.63%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.21%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.64%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.64%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.65%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.65%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.65%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.49%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.51%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.73%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.76%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.90%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.19%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.74%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.63%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.64%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.22%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.51%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.41%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.89%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.10%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.80%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.09%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.02%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.58%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.23%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.47%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.29%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.12%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.17%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.89%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.55%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.39%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.06%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.76%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.47%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.65%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.28%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.33%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.09%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.17%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.47%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.22%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.70%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.09%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.95%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.40%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.33%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.89%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.33%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.53%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.33%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.40%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.62%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.28%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.68%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.49%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.18%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.34%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.43%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.71%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.96%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.46%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.35%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.88%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.10%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.44%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.32%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 9.65%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.63%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 8.95%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.04%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.15%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.14%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.96%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.90%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.36%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.03%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.56%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.41%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.79%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.39%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.23%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.09%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.87%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.48%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.12%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.32%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.32%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.91%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.36%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.07%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.14%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.78%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.25%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.04%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.80%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.10%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.84%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.28%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.68%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 6.38%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 9.18%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 9.63%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.88%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.45%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.56%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.68%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.29%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.01%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.62%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.75%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.52%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.53%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.23%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.45%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.61%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.27%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.32%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.50%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.29%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.36%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.67%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.26%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.43%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.81%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.92%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.80%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.88%.
# Found 4 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.93%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.65%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.65%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.59%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.17%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.97%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.42%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.65%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.94%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 5.83%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.75%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.11%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.04%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.97%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.50%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.27%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.35%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.77%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.45%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.41%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.74%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.59%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.66%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.63%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.23%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.44%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.87%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.53%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.15%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.54%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.57%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.55%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.27%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.30%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.58%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.37%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.04%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.75%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.85%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.60%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.31%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 4.10%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.44%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.18%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.99%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 7.97%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.46%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.58%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.10%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 0.86%.
# Found 3 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.84%.
# Found 1 word(s) missing in the model. Weighted missing percentage not covered by the given model is 1.57%.
# ...
# Found 50 word(s) missing in the model. Weighted missing percentage not covered by the given model is 28.83%.
# Found 76 word(s) missing in the model. Weighted missing percentage not covered by the given model is 38.48%.
# Found 43 word(s) missing in the model. Weighted missing percentage not covered by the given model is 23.11%.
# Found 45 word(s) missing in the model. Weighted missing percentage not covered by the given model is 36.11%.
# Found 19 word(s) missing in the model. Weighted missing percentage not covered by the given model is 32.64%.
# Found 10 word(s) missing in the model. Weighted missing percentage not covered by the given model is 19.42%.
# Found 114 word(s) missing in the model. Weighted missing percentage not covered by the given model is 31.86%.
# Found 103 word(s) missing in the model. Weighted missing percentage not covered by the given model is 26.47%.
# Found 76 word(s) missing in the model. Weighted missing percentage not covered by the given model is 30.42%.
# Found 86 word(s) missing in the model. Weighted missing percentage not covered by the given model is 35.12%.
# Found 84 word(s) missing in the model. Weighted missing percentage not covered by the given model is 28.26%.
# Found 82 word(s) missing in the model. Weighted missing percentage not covered by the given model is 34.83%.
# Found 90 word(s) missing in the model. Weighted missing percentage not covered by the given model is 37.08%.
# Found 23 word(s) missing in the model. Weighted missing percentage not covered by the given model is 37.37%.
# Found 26 word(s) missing in the model. Weighted missing percentage not covered by the given model is 36.92%.
# Found 65 word(s) missing in the model. Weighted missing percentage not covered by the given model is 30.60%.
# Found 31 word(s) missing in the model. Weighted missing percentage not covered by the given model is 23.28%.
# Found 29 word(s) missing in the model. Weighted missing percentage not covered by the given model is 21.89%.
# Found 52 word(s) missing in the model. Weighted missing percentage not covered by the given model is 23.43%.
# Found 17 word(s) missing in the model. Weighted missing percentage not covered by the given model is 34.56%.
# Found 64 word(s) missing in the model. Weighted missing percentage not covered by the given model is 31.27%.
# Found 9 word(s) missing in the model. Weighted missing percentage not covered by the given model is 20.55%.
# Found 57 word(s) missing in the model. Weighted missing percentage not covered by the given model is 20.20%.
# Found 17 word(s) missing in the model. Weighted missing percentage not covered by the given model is 10.91%.
# Found 9 word(s) missing in the model. Weighted missing percentage not covered by the given model is 12.80%.
# Found 9 word(s) missing in the model. Weighted missing percentage not covered by the given model is 70.41%.
# Found 52 word(s) missing in the model. Weighted missing percentage not covered by the given model is 19.85%.
# Found 69 word(s) missing in the model. Weighted missing percentage not covered by the given model is 25.42%.
# Found 73 word(s) missing in the model. Weighted missing percentage not covered by the given model is 37.05%.
# Found 47 word(s) missing in the model. Weighted missing percentage not covered by the given model is 15.14%.
# Found 36 word(s) missing in the model. Weighted missing percentage not covered by the given model is 22.65%.
# Found 50 word(s) missing in the model. Weighted missing percentage not covered by the given model is 26.86%.
# Found 44 word(s) missing in the model. Weighted missing percentage not covered by the given model is 36.34%.
# Found 44 word(s) missing in the model. Weighted missing percentage not covered by the given model is 39.24%.
# Found 9 word(s) missing in the model. Weighted missing percentage not covered by the given model is 40.32%.
# Found 58 word(s) missing in the model. Weighted missing percentage not covered by the given model is 38.07%.
# Found 107 word(s) missing in the model. Weighted missing percentage not covered by the given model is 44.87%.
# Found 100 word(s) missing in the model. Weighted missing percentage not covered by the given model is 20.94%.
# Found 53 word(s) missing in the model. Weighted missing percentage not covered by the given model is 27.89%.
# Found 36 word(s) missing in the model. Weighted missing percentage not covered by the given model is 29.68%.
# Found 72 word(s) missing in the model. Weighted missing percentage not covered by the given model is 27.29%.
# Found 66 word(s) missing in the model. Weighted missing percentage not covered by the given model is 26.11%.
# Found 68 word(s) missing in the model. Weighted missing percentage not covered by the given model is 26.27%.
# Found 6 word(s) missing in the model. Weighted missing percentage not covered by the given model is 10.25%.
# Found 11 word(s) missing in the model. Weighted missing percentage not covered by the given model is 11.92%.
# Found 15 word(s) missing in the model. Weighted missing percentage not covered by the given model is 12.63%.
# Found 20 word(s) missing in the model. Weighted missing percentage not covered by the given model is 42.93%.
# Found 57 word(s) missing in the model. Weighted missing percentage not covered by the given model is 16.74%.
# Found 73 word(s) missing in the model. Weighted missing percentage not covered by the given model is 23.92%.
# Found 88 word(s) missing in the model. Weighted missing percentage not covered by the given model is 23.93%.
# Found 60 word(s) missing in the model. Weighted missing percentage not covered by the given model is 19.60%.
# Found 90 word(s) missing in the model. Weighted missing percentage not covered by the given model is 40.56%.
# Found 86 word(s) missing in the model. Weighted missing percentage not covered by the given model is 32.50%.
# Found 19 word(s) missing in the model. Weighted missing percentage not covered by the given model is 17.76%.
# Found 71 word(s) missing in the model. Weighted missing percentage not covered by the given model is 21.45%.
# Found 2 word(s) missing in the model. Weighted missing percentage not covered by the given model is 2.55%.
# Found 85 word(s) missing in the model. Weighted missing percentage not covered by the given model is 28.76%.
# Found 121 word(s) missing in the model. Weighted missing percentage not covered by the given model is 34.79%.
# Found 88 word(s) missing in the model. Weighted missing percentage not covered by the given model is 36.04%.
# Found 81 word(s) missing in the model. Weighted missing percentage not covered by the given model is 34.70%.
# Found 98 word(s) missing in the model. Weighted missing percentage not covered by the given model is 27.47%.
# Found 49 word(s) missing in the model. Weighted missing percentage not covered by the given model is 20.93%.
# Found 32 word(s) missing in the model. Weighted missing percentage not covered by the given model is 31.07%.
# Found 19 word(s) missing in the model. Weighted missing percentage not covered by the given model is 33.10%.
# Found 14 word(s) missing in the model. Weighted missing percentage not covered by the given model is 25.31%.
# Found 14 word(s) missing in the model. Weighted missing percentage not covered by the given model is 23.25%.
# Found 39 word(s) missing in the model. Weighted missing percentage not covered by the given model is 38.07%.
# Found 42 word(s) missing in the model. Weighted missing percentage not covered by the given model is 45.32%.
# Found 48 word(s) missing in the model. Weighted missing percentage not covered by the given model is 24.23%.
# Found 11 word(s) missing in the model. Weighted missing percentage not covered by the given model is 18.74%.
# Found 9 word(s) missing in the model. Weighted missing percentage not covered by the given model is 24.22%.
# Found 88 word(s) missing in the model. Weighted missing percentage not covered by the given model is 38.91%.
# Found 132 word(s) missing in the model. Weighted missing percentage not covered by the given model is 44.10%.
# Found 27 word(s) missing in the model. Weighted missing percentage not covered by the given model is 41.77%.
# Found 27 word(s) missing in the model. Weighted missing percentage not covered by the given model is 49.33%.
# Found 7 word(s) missing in the model. Weighted missing percentage not covered by the given model is 36.03%.
# Found 39 word(s) missing in the model. Weighted missing percentage not covered by the given model is 46.40%.
# Found 51 word(s) missing in the model. Weighted missing percentage not covered by the given model is 31.93%.
# Found 79 word(s) missing in the model. Weighted missing percentage not covered by the given model is 38.01%.
# Found 80 word(s) missing in the model. Weighted missing percentage not covered by the given model is 37.47%.
# Found 122 word(s) missing in the model. Weighted missing percentage not covered by the given model is 35.22%.
# Found 104 word(s) missing in the model. Weighted missing percentage not covered by the given model is 41.91%.
# Found 6 word(s) missing in the model. Weighted missing percentage not covered by the given model is 3.97%.
# Found 62 word(s) missing in the model. Weighted missing percentage not covered by the given model is 21.65%.
# Found 19 word(s) missing in the model. Weighted missing percentage not covered by the given model is 16.57%.
# Found 66 word(s) missing in the model. Weighted missing percentage not covered by the given model is 19.59%.
# Found 4 word(s) missing in the model. Weighted missing percentage not covered by the given model is 16.58%.
# Found 13 word(s) missing in the model. Weighted missing percentage not covered by the given model is 27.42%.
# Found 86 word(s) missing in the model. Weighted missing percentage not covered by the given model is 30.99%.
# Found 19 word(s) missing in the model. Weighted missing percentage not covered by the given model is 24.63%.
# Found 26 word(s) missing in the model. Weighted missing percentage not covered by the given model is 34.98%.
# Found 75 word(s) missing in the model. Weighted missing percentage not covered by the given model is 19.11%.
# Found 99 word(s) missing in the model. Weighted missing percentage not covered by the given model is 20.45%.
# Found 60 word(s) missing in the model. Weighted missing percentage not covered by the given model is 45.17%.
# Found 7 word(s) missing in the model. Weighted missing percentage not covered by the given model is 50.55%.
# Found 45 word(s) missing in the model. Weighted missing percentage not covered by the given model is 33.65%.
# Found 68 word(s) missing in the model. Weighted missing percentage not covered by the given model is 27.47%.
# Found 70 word(s) missing in the model. Weighted missing percentage not covered by the given model is 30.56%.
# Found 29 word(s) missing in the model. Weighted missing percentage not covered by the given model is 14.11%.
# Found 25 word(s) missing in the model. Weighted missing percentage not covered by the given model is 31.55%.
# Found 29 word(s) missing in the model. Weighted missing percentage not covered by the given model is 35.74%.
# Found 105 word(s) missing in the model. Weighted missing percentage not covered by the given model is 21.99%.
# Found 34 word(s) missing in the model. Weighted missing percentage not covered by the given model is 38.27%.
# Found 55 word(s) missing in the model. Weighted missing percentage not covered by the given model is 30.84%.
# Found 172 word(s) missing in the model. Weighted missing percentage not covered by the given model is 30.51%.
# Found 103 word(s) missing in the model. Weighted missing percentage not covered by the given model is 32.57%.
# Found 74 word(s) missing in the model. Weighted missing percentage not covered by the given model is 13.41%.
# Found 33 word(s) missing in the model. Weighted missing percentage not covered by the given model is 10.67%.
# Found 4 word(s) missing in the model. Weighted missing percentage not covered by the given model is 12.83%.
# Found 42 word(s) missing in the model. Weighted missing percentage not covered by the given model is 22.06%.
# Found 20 word(s) missing in the model. Weighted missing percentage not covered by the given model is 25.41%.
# Found 105 word(s) missing in the model. Weighted missing percentage not covered by the given model is 38.98%.
# Found 85 word(s) missing in the model. Weighted missing percentage not covered by the given model is 21.26%.
# Found 52 word(s) missing in the model. Weighted missing percentage not covered by the given model is 15.47%.
# Found 28 word(s) missing in the model. Weighted missing percentage not covered by the given model is 19.66%.
# Found 67 word(s) missing in the model. Weighted missing percentage not covered by the given model is 23.33%.
# Found 57 word(s) missing in the model. Weighted missing percentage not covered by the given model is 41.95%.
# Found 73 word(s) missing in the model. Weighted missing percentage not covered by the given model is 45.63%.
# Found 44 word(s) missing in the model. Weighted missing percentage not covered by the given model is 24.50%.
# Found 81 word(s) missing in the model. Weighted missing percentage not covered by the given model is 31.90%.
# Found 95 word(s) missing in the model. Weighted missing percentage not covered by the given model is 23.25%.
# Found 156 word(s) missing in the model. Weighted missing percentage not covered by the given model is 27.91%.
# Found 156 word(s) missing in the model. Weighted missing percentage not covered by the given model is 31.79%.
# Found 143 word(s) missing in the model. Weighted missing percentage not covered by the given model is 26.06%.
# Found 98 word(s) missing in the model. Weighted missing percentage not covered by the given model is 29.72%.
# Found 75 word(s) missing in the model. Weighted missing percentage not covered by the given model is 19.93%.
# Found 83 word(s) missing in the model. Weighted missing percentage not covered by the given model is 21.44%.
# Found 81 word(s) missing in the model. Weighted missing percentage not covered by the given model is 33.56%.
# Found 62 word(s) missing in the model. Weighted missing percentage not covered by the given model is 29.23%.
# Found 47 word(s) missing in the model. Weighted missing percentage not covered by the given model is 35.91%.
# Found 38 word(s) missing in the model. Weighted missing percentage not covered by the given model is 16.16%.
# Found 201 word(s) missing in the model. Weighted missing percentage not covered by the given model is 58.61%.
# Found 39 word(s) missing in the model. Weighted missing percentage not covered by the given model is 18.35%.
# Found 57 word(s) missing in the model. Weighted missing percentage not covered by the given model is 22.16%.
# Found 80 word(s) missing in the model. Weighted missing percentage not covered by the given model is 28.39%.
# Found 91 word(s) missing in the model. Weighted missing percentage not covered by the given model is 26.18%.
# Found 62 word(s) missing in the model. Weighted missing percentage not covered by the given model is 23.68%.
# Found 156 word(s) missing in the model. Weighted missing percentage not covered by the given model is 27.20%.
# Found 19 word(s) missing in the model. Weighted missing percentage not covered by the given model is 15.49%.
# Found 61 word(s) missing in the model. Weighted missing percentage not covered by the given model is 37.37%.
# Found 35 word(s) missing in the model. Weighted missing percentage not covered by the given model is 37.80%.
# Found 161 word(s) missing in the model. Weighted missing percentage not covered by the given model is 39.41%.
# Found 163 word(s) missing in the model. Weighted missing percentage not covered by the given model is 38.98%.
# Found 13 word(s) missing in the model. Weighted missing percentage not covered by the given model is 16.96%.
# Found 7 word(s) missing in the model. Weighted missing percentage not covered by the given model is 20.94%.
# Found 161 word(s) missing in the model. Weighted missing percentage not covered by the given model is 29.85%.

# %%
matrix_similarities_fingerprint_daylight.shape

# %%
path_models = "gas2vec"

iteration=100

filename = f"{model_name}.model"
model_file = os.path.join(path_models, filename)

# Load pretrained model
model = gensim.models.Word2Vec.load(model_file)
    
# Score calculations
spec2vec_similarity = Spec2Vec(model, intensity_weighting_power=0.5, allowed_missing_percentage=15)
similarity_matrix = spec2vec_similarity.matrix(documents, documents, is_symmetric=True)
# Compare to reference scores
percentile_spec2vec = plot_precentile(matrix_similarities_fingerprint_daylight,
                                                      similarity_matrix,
                                                      num_bins=100, show_top_percentile=0.1,
                                                      ignore_diagonal=True)

filename = os.path.join("gas2vec/iterations", "percentile_spec2vec_only10k_iter_{}.npy".format(iteration))
np.save(filename, percentile_spec2vec)
    
filename = os.path.join("gas2vec/iterations", "similarities_spec2vec_only10k_iter_{}.npy".format(iteration))
np.save(filename, percentile_spec2vec)

# %% [markdown]
# ## Compare results

# %%
path_data = "gas2vec/iterations"

percentiles = []
for iteration in [2, 4, 6, 10, 16, 20, 26, 30, 40, 50, 60, 70, 80, 90, 100]:
    
    filename = os.path.join(path_data, "percentile_spec2vec_only10k_iter_{}.npy".format(iteration))
    percentiles.append(np.load(filename))

# %%
from matplotlib import pyplot as plt

#Compare all:
num_bins = 100
show_top_percentile = 0.1

plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(7,6))

x_percentiles = (show_top_percentile / num_bins * (1 + np.arange(num_bins)))[::-1]
iterations = [2, 4, 6, 10, 16, 20, 26, 30, 40, 50, 60, 70, 80, 90, 100]
iterations_plot = [2, 4, 6, 10, 16, 20, 26, 30, 40, 50, 60, 70, 80, 90, 100]

color_count = 0
color_max = len(iterations_plot) + 1
for i, percentile in enumerate(percentiles):
    if iterations[i] in iterations_plot:
        plt.plot(x_percentiles, percentiles[i], 
                 color=(color_count/color_max, 0, 1-color_count/color_max, 0.2+0.8*color_count/color_max),
                 label='{}) Spec2Vec (trained {} iterations on UniqueInchikeys)'.format((color_count+1), iterations[i]))
        color_count += 1

i = 9    
# plt.plot(x_percentiles, percentiles[i], 
#          "--", color="black",
#          label='selected: Spec2Vec (trained {} iterations on UniqueInchikeys)'.format(iterations[i]))
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xticks(np.linspace(0, show_top_percentile, 5),
           ["{:.3f}%".format(x) for x in np.linspace(0, show_top_percentile, 5)])
plt.legend(fontsize=8)
plt.xlabel("Top percentile of spectral similarity score g(s1,s2)", fontsize=13)
plt.ylabel("Mean molecular similarity f(m1,m2) \n (within respective percentile)", fontsize=13)
plt.xlim(0, 0.1)
plt.ylim(0.4, 0.92)
plt.savefig(os.path.join("gas2vec/figures", 'Benchmarking_model_only10k_iterations.pdf'))

# %% [markdown]
# ---

# %%
import os
import sys
import gensim
import numpy as np

base = "data"
dataset = "nist"
kind = "in_database"

model_name = kind 

data_train_path =f"{base}/{dataset}/{kind}/train.msp"
data_val_path =f"{base}/{dataset}/{kind}/val.msp"
data_test_path =f"{base}/{dataset}/{kind}/test.msp"

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Import pre-processed dataset "Unique InchiKeys"

# %%
from matchms.importing import load_from_msp
from data_utils import spectrum_processing

spectrums_val = [spectrum_processing(s) for s in load_from_msp(data_val_path)]
spectrums_val = [s for s in spectrums_val if s is not None]
print("number of spectra:", len(spectrums_val))
# Out:
# number of spectra: 22921

# %% [markdown]
# ## Load pretrained spec2vec models and calculate scores

# %%
from spec2vec import Spec2Vec
from spec2vec import SpectrumDocument

# %%
documents = [SpectrumDocument(s, n_decimals=0) for s in spectrums_val]

# %%
documents[0].words[:10]
# Out:
# ['peak@12',
#  'peak@13',
#  'peak@14',
#  'peak@15',
#  'peak@24',
#  'peak@25',
#  'peak@26',
#  'peak@27',
#  'peak@28',
#  'peak@29']

# %% [markdown]
# ### Load reference scores

# %%
filename = "gas2vec/similarity_nist_val/in_database/tanimoto_scores.npy"
matrix_similarities_fingerprint_daylight = np.load(filename)

# %%
from spec2vec_plotting_functions import plot_precentile

# %% [markdown]
# ## Actual score calculation
# + Using ``Spec2Vec`` with ``intensity_weighting_power=0.5``.
# + Calculate matrix of all-vs-all similarity scores.
# + Iterate over trained models after different numbers of iterations.

# %%
# !pwd
# Out:
# /auto/brno6/home/xstary1/raims

# %%
path_models = "gas2vec"

for iteration in [2, 4, 6, 10, 16, 20, 26, 30, 40, 50, 60, 70, 80, 90, 100]:
    filename = f"{model_name}_iter_{iteration}.model"
    model_file = os.path.join(path_models, filename)

    # Load pretrained model
    model = gensim.models.Word2Vec.load(model_file)
    
    # Score calculations
    spec2vec_similarity = Spec2Vec(model, intensity_weighting_power=0.5, allowed_missing_percentage=15)
    similarity_matrix = spec2vec_similarity.matrix(documents, documents, is_symmetric=True)
    print("u")
    # Compare to reference scores
    percentile_spec2vec = plot_precentile(matrix_similarities_fingerprint_daylight,
                                                      similarity_matrix,
                                                      num_bins=100, show_top_percentile=0.1,
                                                      ignore_diagonal=True)

    filename = os.path.join("gas2vec/iterations", "percentile_gas2vec_iter_{}.npy".format(iteration))
    np.save(filename, percentile_spec2vec)
    
    filename = os.path.join("gas2vec/iterations", "similarities_gas2vec_iter_{}.npy".format(iteration))
    np.save(filename, percentile_spec2vec)
# Out:
# u
# u
# u
# u
# u
# u
# u
# u
# u
# u
# u
# u
# u
# u
# u

# %%
path_models = "gas2vec"

iteration=100

filename = f"{model_name}.model"
model_file = os.path.join(path_models, filename)

# Load pretrained model
model = gensim.models.Word2Vec.load(model_file)
    
# Score calculations
spec2vec_similarity = Spec2Vec(model, intensity_weighting_power=0.5, allowed_missing_percentage=15)
similarity_matrix = spec2vec_similarity.matrix(documents, documents, is_symmetric=True)
# Compare to reference scores
percentile_spec2vec = plot_precentile(matrix_similarities_fingerprint_daylight,
                                                      similarity_matrix,
                                                      num_bins=100, show_top_percentile=0.1,
                                                      ignore_diagonal=True)

filename = os.path.join("gas2vec/iterations", "percentile_gas2vec_iter_{}.npy".format(iteration))
np.save(filename, percentile_spec2vec)
    
filename = os.path.join("gas2vec/iterations", "similarities_gas2vec_iter_{}.npy".format(iteration))
np.save(filename, percentile_spec2vec)

# %% [markdown]
# ## Compare results

# %%
path_data = "gas2vec/iterations"

percentiles = []
for iteration in [2, 4, 6, 10, 16, 20, 26, 30, 40, 50, 60, 70, 80, 90, 100]:
    
    filename = os.path.join(path_data, "percentile_gas2vec_iter_{}.npy".format(iteration))
    percentiles.append(np.load(filename))

# %%
from matplotlib import pyplot as plt

#Compare all:
num_bins = 100
show_top_percentile = 0.1

plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(7,6))

x_percentiles = (show_top_percentile / num_bins * (1 + np.arange(num_bins)))[::-1]
iterations = [2, 4, 6, 10, 16, 20, 26, 30, 40, 50, 60, 70, 80, 90, 100]
iterations_plot = [2, 4, 6, 10, 16, 20, 26, 30, 40, 50, 60, 70, 80, 90, 100]

color_count = 0
color_max = len(iterations_plot) + 1
for i, percentile in enumerate(percentiles):
    if iterations[i] in iterations_plot:
        plt.plot(x_percentiles, percentiles[i], 
                 color=(color_count/color_max, 0, 1-color_count/color_max, 0.2+0.8*color_count/color_max),
                 label='{}) Spec2Vec (trained {} iterations on UniqueInchikeys)'.format((color_count+1), iterations[i]))
        color_count += 1

i = 9    
# plt.plot(x_percentiles, percentiles[i], 
#          "--", color="black",
#          label='selected: Spec2Vec (trained {} iterations on UniqueInchikeys)'.format(iterations[i]))
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xticks(np.linspace(0, show_top_percentile, 5),
           ["{:.3f}%".format(x) for x in np.linspace(0, show_top_percentile, 5)])
plt.legend(fontsize=8)
plt.xlabel("Top percentile of spectral similarity score g(s1,s2)", fontsize=13)
plt.ylabel("Mean molecular similarity f(m1,m2) \n (within respective percentile)", fontsize=13)
plt.xlim(0, 0.1)
plt.ylim(0.4, 0.92)
plt.savefig(os.path.join("gas2vec/figures", 'Benchmarking_model_iterations.pdf'))
plt.savefig(os.path.join("gas2vec/figures", 'Benchmarking_model_iterations.eps'))
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ---
