# %%
import numpy as np
from collections import Counter

# %%
base = "data"
dataset = "nist"
kind = "in_database"

data_train_path =f"{base}/{dataset}/{kind}/train.msp"
data_val_path =f"{base}/{dataset}/{kind}/val.msp"
data_test_path =f"{base}/{dataset}/{kind}/test.msp"

max_mz = 1001

# %load_ext autoreload
# %autoreload 2
P_FOLDER = f"predictions/{kind}"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def load_predictions(p_name, d_name, P_FOLDER):
    l_pred_indices_per_k = np.load(f"{P_FOLDER}/{d_name}/{p_name}/l_pred_indices_per_k.npy")
    y_indices = np.load(f"{P_FOLDER}/{d_name}/{p_name}/y_indices.npy", allow_pickle=True)
    X_intens =  np.load(f"{P_FOLDER}/{d_name}/{p_name}/X_intens.npy", allow_pickle=True)
    
    return l_pred_indices_per_k, y_indices, X_intens

# %%
l_pred_indices_per_k, y_indices, X_intens = load_predictions("specknn_1", "spec_test", P_FOLDER)

# %%
import seaborn as sns

# %%
Counter(l_pred_indices_per_k[3][:, :5].ravel())
sns.countplot(l_pred_indices_per_k[3][:, :5].ravel())
# Out:
# /storage/brno6/home/xstary1/.local-Pytorch-21.SIF/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
Counter(l_pred_indices_per_k[3][:, :5].ravel()).most_common()
# Out:
# [(39.0, 4105),
#  (41.0, 3582),
#  (27.0, 2541),
#  (43.0, 2513),
#  (55.0, 2408),
#  (77.0, 2408),
#  (42.0, 2362),
#  (29.0, 2266),
#  (51.0, 2131),
#  (65.0, 1745),
#  (45.0, 1739),
#  (69.0, 1539),
#  (91.0, 1526),
#  (57.0, 1412),
#  (63.0, 1409),
#  (56.0, 1266),
#  (75.0, 1229),
#  (28.0, 1156),
#  (79.0, 1130),
#  (53.0, 1120),
#  (44.0, 1052),
#  (78.0, 956),
#  (67.0, 942),
#  (92.0, 911),
#  (50.0, 907),
#  (70.0, 907),
#  (59.0, 888),
#  (74.0, 878),
#  (81.0, 862),
#  (105.0, 808),
#  (103.0, 797),
#  (93.0, 794),
#  (83.0, 774),
#  (89.0, 769),
#  (107.0, 763),
#  (115.0, 710),
#  (71.0, 690),
#  (121.0, 683),
#  (95.0, 653),
#  (58.0, 643),
#  (109.0, 640),
#  (76.0, 619),
#  (73.0, 606),
#  (119.0, 598),
#  (106.0, 593),
#  (104.0, 589),
#  (52.0, 586),
#  (85.0, 562),
#  (82.0, 551),
#  (117.0, 542),
#  (40.0, 537),
#  (31.0, 530),
#  (54.0, 524),
#  (96.0, 497),
#  (30.0, 496),
#  (68.0, 489),
#  (135.0, 484),
#  (108.0, 484),
#  (120.0, 481),
#  (133.0, 476),
# ...

# %%
sns.countplot(np.array([y[3:3+5] for y in y_indices]).ravel())
# Out:
# /storage/brno6/home/xstary1/.local-Pytorch-21.SIF/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
l_pred_indices_per_k_gpt, y_indices_gpt, X_intens_gpt = load_predictions("gpt2_ns_auto", "hugg_test", P_FOLDER)

# %%
sns.countplot(l_pred_indices_per_k_gpt[3][:, :5].ravel())
# Out:
# /storage/brno6/home/xstary1/.local-Pytorch-21.SIF/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
sns.countplot(np.array([y[3:3+5] for y in y_indices_gpt]).ravel())
# Out:
# /storage/brno6/home/xstary1/.local-Pytorch-21.SIF/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
Counter(l_pred_indices_per_k_gpt[3][:, :5].ravel()).most_common()
# Out:
# [(0.0, 5974),
#  (6.0, 5393),
#  (1.0, 4984),
#  (2.0, 4489),
#  (7.0, 3654),
#  (5.0, 3048),
#  (3.0, 2920),
#  (68.0, 2817),
#  (71.0, 2733),
#  (8.0, 2731),
#  (9.0, 2076),
#  (10.0, 1981),
#  (16.0, 1929),
#  (23.0, 1872),
#  (13.0, 1786),
#  (11.0, 1644),
#  (30.0, 1626),
#  (21.0, 1572),
#  (14.0, 1465),
#  (18.0, 1309),
#  (19.0, 1308),
#  (24.0, 1277),
#  (15.0, 1245),
#  (12.0, 1210),
#  (4.0, 1155),
#  (32.0, 1153),
#  (17.0, 1135),
#  (27.0, 1023),
#  (31.0, 959),
#  (43.0, 956),
#  (77.0, 870),
#  (37.0, 812),
#  (25.0, 797),
#  (121.0, 763),
#  (45.0, 761),
#  (20.0, 757),
#  (26.0, 748),
#  (40.0, 748),
#  (36.0, 694),
#  (35.0, 691),
#  (42.0, 654),
#  (57.0, 524),
#  (29.0, 505),
#  (66.0, 499),
#  (93.0, 489),
#  (64.0, 436),
#  (60.0, 418),
#  (102.0, 413),
#  (65.0, 410),
#  (62.0, 410),
#  (48.0, 391),
#  (67.0, 385),
#  (28.0, 384),
#  (44.0, 376),
#  (56.0, 376),
#  (58.0, 374),
#  (33.0, 354),
#  (54.0, 352),
#  (125.0, 350),
#  (99.0, 346),
#  (41.0, 345),
# ...
